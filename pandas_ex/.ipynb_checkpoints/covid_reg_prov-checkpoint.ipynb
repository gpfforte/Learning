# %%
import os
import pandas as pd

# %%
# print(os.listdir())
df_province = pd.read_csv(
    "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv")
df_regioni = pd.read_csv(
    "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni.csv")

# %%
# pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 200)

df_regioni.tail()
df_liguria = df_regioni.loc[df_regioni.loc[:,"codice_regione"]==7].copy()
df_liguria["tamponi_effettuati"] = df_liguria["tamponi"]-df_liguria["tamponi"].shift(1)
# print(df_liguria.loc[:,"nuovi_positivi"])
df_liguria["perc_positivi"] = df_liguria["nuovi_positivi"]/df_liguria["tamponi_effettuati"]*100
filt = df_liguria.loc[:,"data"] >= "2021-12-01T00:00:00"
df_liguria = df_liguria.loc[filt]
# print (df_liguria.columns)
df_liguria.tail()
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 13867  2021-12-15T17:00:00   ITA               7               Liguria
# 13888  2021-12-16T17:00:00   ITA               7               Liguria
# 13909  2021-12-17T17:00:00   ITA               7               Liguria
# 13930  2021-12-18T17:00:00   ITA               7               Liguria
# 13951  2021-12-19T17:00:00   ITA               7               Liguria
#
#              lat      long  ricoverati_con_sintomi  terapia_intensiva  \
# 13867  44.411493  8.932699                     300                 28
# 13888  44.411493  8.932699                     315                 31
# 13909  44.411493  8.932699                     337                 29
# 13930  44.411493  8.932699                     337                 31
# 13951  44.411493  8.932699                     347                 29
#
#        totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 13867                   328                    6573             6901
# 13888                   346                    7002             7348
# 13909                   366                    7190             7556
# 13930                   368                    7758             8126
# 13951                   376                    8122             8498
#
#        variazione_totale_positivi  nuovi_positivi  dimessi_guariti  deceduti  \
# 13867                         -24             807           119106      4503
# 13888                         447            1011           119666      4507
# 13909                         208            1023           120476      4512
# 13930                         570            1007           120909      4516
# 13951                         372             754           121287      4520
#
#        casi_da_sospetto_diagnostico  casi_da_screening  totale_casi  tamponi  \
# 13867                           NaN                NaN       130510  3247226
# 13888                           NaN                NaN       131521  3266546
# 13909                           NaN                NaN       132544  3283675
# 13930                           NaN                NaN       133551  3302283
# 13951                           NaN                NaN       134305  3316170
#
#        casi_testati                                               note  \
# 13867      994118.0  In Regione Liguria la positività al test antig...
# 13888      996674.0  In Regione Liguria la positività al test antig...
# 13909      999085.0  In Regione Liguria la positività al test antig...
# 13930     1002018.0  In Regione Liguria la positività al test antig...
# 13951     1004355.0  In Regione Liguria la positività al test antig...
#
#        ingressi_terapia_intensiva note_test  \
# 13867                         3.0       NaN
# 13888                         4.0       NaN
# 13909                         1.0       NaN
# 13930                         3.0       NaN
# 13951                         5.0       NaN
#
#                                                note_casi  \
# 13867  *di cui 231 reinfezioni a partire dal 3/09/202...
# 13888  *di cui 247 reinfezioni a partire dal 3/09/202...
# 13909  *di cui 259 reinfezioni a partire dal 3/09/202...
# 13930  *di cui 274 reinfezioni a partire dal 3/09/202...
# 13951  *di cui 281 reinfezioni a partire dal 3/09/202...
#
#        totale_positivi_test_molecolare  \
# 13867                         130510.0
# 13888                         131521.0
# 13909                         132544.0
# 13930                         133551.0
# 13951                         134305.0
#
#        totale_positivi_test_antigenico_rapido  tamponi_test_molecolare  \
# 13867                                     0.0                1890657.0
# 13888                                     0.0                1897040.0
# 13909                                     0.0                1903331.0
# 13930                                     0.0                1909756.0
# 13951                                     0.0                1915006.0
#
#        tamponi_test_antigenico_rapido codice_nuts_1 codice_nuts_2  \
# 13867                       1356569.0           ITC          ITC3
# 13888                       1369506.0           ITC          ITC3
# 13909                       1380344.0           ITC          ITC3
# 13930                       1392527.0           ITC          ITC3
# 13951                       1401164.0           ITC          ITC3
#
#        tamponi_effettuati  perc_positivi
# 13867             16506.0       4.889131
# 13888             19320.0       5.232919
# 13909             17129.0       5.972328
# 13930             18608.0       5.411651
# 13951             13887.0       5.429538

# %%
df_province.tail()
df_imperia = df_province[df_province["codice_provincia"]==8]
df_imperia.tail()
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 95826  2021-12-15T17:00:00   ITA               7               Liguria
# 95975  2021-12-16T17:00:00   ITA               7               Liguria
# 96124  2021-12-17T17:00:00   ITA               7               Liguria
# 96273  2021-12-18T17:00:00   ITA               7               Liguria
# 96422  2021-12-19T17:00:00   ITA               7               Liguria
#
#        codice_provincia denominazione_provincia sigla_provincia        lat  \
# 95826                 8                 Imperia              IM  43.885706
# 95975                 8                 Imperia              IM  43.885706
# 96124                 8                 Imperia              IM  43.885706
# 96273                 8                 Imperia              IM  43.885706
# 96422                 8                 Imperia              IM  43.885706
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 95826  8.02785        19986  NaN           ITC          ITC3         ITC31
# 95975  8.02785        20319  NaN           ITC          ITC3         ITC31
# 96124  8.02785        20676  NaN           ITC          ITC3         ITC31
# 96273  8.02785        20898  NaN           ITC          ITC3         ITC31
# 96422  8.02785        21137  NaN           ITC          ITC3         ITC31

# %%
# %matplotlib inline
df_liguria["perc_positivi"].plot()
# Out:
# <AxesSubplot:>
