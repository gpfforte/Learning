# %%
import pandas as pd
url = "https://it.wikipedia.org/wiki/Prefissi_telefonici_italiani"
df1 = pd.read_html(url)
df = df1[0]
print(type(df.columns))
print(df.columns)
converters = {c:lambda c: str(c) for c in df.columns}
# print(converters)
# converters = {i:str for i in range(len(df.columns))}
print(converters)
print(len(df.columns))
df = pd.read_html(url, converters=converters)[0]


df.to_excel("prefissi_italiani.xlsx", index=False)
df
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Prefisso[4]', 'Compartimento', 'Distretto', 'Altre città[5]',
#        'Aree locali', 'Provincia'],
#       dtype='object')
# {'Prefisso[4]': <function <lambda> at 0x79bcd55294e0>, 'Compartimento': <function <lambda> at 0x79bcd55293a0>, 'Distretto': <function <lambda> at 0x79bcd5529440>, 'Altre città[5]': <function <lambda> at 0x79bcd5529080>, 'Aree locali': <function <lambda> at 0x79bcd5528fe0>, 'Provincia': <function <lambda> at 0x79bcd5529760>}
# 6
#     Prefisso[4]      Compartimento               Distretto  \
# 0        004191  Lugano (Svizzera)  Campione d'Italia (CO)
# 1           010             Genova                  Genova
# 2           011             Torino                  Torino
# 3          0121             Torino           Pinerolo (TO)
# 4          0122             Torino               Susa (TO)
# ..          ...                ...                     ...
# 228        0982          Catanzaro              Paola (CS)
# ...

# %%
len(df1)
df1[1]
df1
# Out:
# [     Prefisso[4]      Compartimento               Distretto  \
#  0           4191  Lugano (Svizzera)  Campione d'Italia (CO)
#  1             10             Genova                  Genova
#  2             11             Torino                  Torino
#  3            121             Torino           Pinerolo (TO)
#  4            122             Torino               Susa (TO)
#  ..           ...                ...                     ...
#  228          982          Catanzaro              Paola (CS)
#  229          983          Catanzaro            Rossano (CS)
#  230          984          Catanzaro                 Cosenza
#  231          985          Catanzaro             Scalea (CS)
#  232           99               Bari                 Taranto
#
#                     Altre città[5]  \
#  0                             NaN
#  1                             NaN
#  2    Moncalieri (TO), Rivoli (TO)
#  3                             NaN
#  4                             NaN
# ...
